# %%
import matplotlib.pyplot as plt

# %%
#import matplotlib.pyplop as plt

# %%
x = [0,2,4,6,8,10]
y = [89,67,45,65,23,67]

plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.title('Ventas')
plt.show()

# %%
plt.plot(x,y)
plt.title('Ventas')
plt.xlabel('Días')
plt.ylabel('Número de ventas')
plt.show()

# %%
experiencia = [1,3,5,7,8]
salario_data_scientists = [3434, 6436, 2343, 4656, 8999]
salario_ing_software = [3344,63446,2343,46456,84599]

# %%
plt.plot(experiencia, salario_data_scientists)
plt.plot(experiencia, salario_ing_software)
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias') 
plt.show()

# %%
plt.plot(experiencia, salario_data_scientists)
plt.plot(experiencia, salario_ing_software)
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias') 
plt.legend(['Data scientist','Ing Software'])
plt.show()

# %%
plt.plot(experiencia, salario_data_scientists, color = 'r', label = 'Data scientists', linestyle = '--', marker = 'o')
plt.plot(experiencia, salario_ing_software, color = 'g', label = 'Ing software', linestyle = ':', marker = '*')
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias') 
plt.legend()
plt.grid(color='r',linestyle='-',linewidth=2)
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y = [3,8,1,10]

plt.bar(x,y)
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias')
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y = [3,8,1,10]

tendencia = [3,8,1,10]

plt.bar(x,y)
plt.plot(x,tendencia,color = 'r')
plt.title('Salarios')
plt.xlabel('Experiencia')
plt.ylabel('Ganancias')
plt.show()

# %%
import numpy as np

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.scatter(x,y, color='r',alpha=0.5)
plt.title('Gráfico de dispersión')
plt.show()

# %%
datos = np.random.randn(10000)

plt.hist(datos,bins=10)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

# %%
datos = [np.random.normal(0,std,100) for std in range (1,4)]
plt.boxplot(datos,vert=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
data_range = pd.date_range(start='2023-01-01', end='2023-12-31',freq='D')
precios = np.cumsum(np.random.randn(len(data_range)))+ 100

# %%
data = pd.DataFrame({'Date': data_range,'Precios':precios})
data.head()
# Out:
#         Date    Precios
# 0 2023-01-01  99.460136
# 1 2023-01-02  99.172816
# 2 2023-01-03  99.333627
# 3 2023-01-04  98.140242
# 4 2023-01-05  97.376774

# %%
plt.plot(data['Date'], data['Precios'],label='Precio')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Ejercicio 2

# %%
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)

categorias = ['a','b','c','d']
valores = [5,6,3,8]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para los gráficos iniciales
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
categorias = ['A', 'B', 'C', 'D']
valores = [10, 20, 15, 25]

# Crear una figura con 4 subplots (2x2)
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Gráfico de líneas
axs[0, 0].plot(x, y1, label='Seno')
axs[0, 0].plot(x, y2, label='Coseno')
axs[0, 0].set_title('Gráfico de líneas')
axs[0, 0].legend(loc='upper right')
axs[0, 0].grid(True)
axs[0, 0].set_xlabel('Eje X')
axs[0, 0].set_ylabel('Eje Y')

# Gráfico de barras
axs[0, 1].bar(categorias, valores)
axs[0, 1].set_title('Gráfico de barras')
axs[0, 1].set_xlabel('Categorías')
axs[0, 1].set_ylabel('Valores')
axs[0, 1].grid(True, axis='y')

# Datos para el gráfico de dispersión
x_scatter = np.random.rand(100)
y_scatter = np.random.rand(100)

# Gráfico de dispersión
axs[1, 0].scatter(x_scatter, y_scatter, color='r', alpha=0.5)
axs[1, 0].set_title('Gráfico de dispersión')
axs[1, 0].set_xlabel('Eje X')
axs[1, 0].set_ylabel('Eje Y')
axs[1, 0].grid(True)

# Datos para el gráfico de caja
datos_boxplot = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Gráfico de caja
axs[1, 1].boxplot(datos_boxplot, vert=False)
axs[1, 1].set_title('Gráfico de caja')
axs[1, 1].set_xlabel('Valores')
axs[1, 1].set_yticklabels(['Desviación 1', 'Desviación 2', 'Desviación 3'])
axs[1, 1].grid(True)

# Mostrar todos los gráficos
plt.show()
